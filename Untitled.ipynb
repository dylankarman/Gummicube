# %%
# importing necessary packages and importing the csv file.
import pandas as pd
import matplotlib as plt
# %matplotlib inline
import seaborn as sns

df = pd.read_csv('SampleApp (2).csv')

# %%
# taking a look at the dataframe to see if it imported properly.
df.head()
# Out:
#          Name                Sample App                    Unnamed: 2  \
# 0  Start Date                 4/15/2017                           NaN
# 1    End Date                  2/1/2021                           NaN
# 2         NaN                       NaN                           NaN
# 3        Date  App Referrer Impressions  App Store Browse Impressions
# 4   4/15/2017                      4333                         95458
#
#                      Unnamed: 3               Unnamed: 4  \
# 0                           NaN                      NaN
# 1                           NaN                      NaN
# 2                           NaN                      NaN
# 3  App Store Search Impressions  Unavailable Impressions
# 4                         24877                        0
#
#                  Unnamed: 5              Unnamed: 6  \
# 0                       NaN                     NaN
# 1                       NaN                     NaN
# 2                       NaN                     NaN
# 3  Web Referrer Impressions  App Referrer App Units
# 4                      5290                     827
#
#                    Unnamed: 7                  Unnamed: 8  \
# 0                         NaN                         NaN
# 1                         NaN                         NaN
# 2                         NaN                         NaN
# 3  App Store Browse App Units  App Store Search App Units
# 4                         363                        4290
#
#               Unnamed: 9             Unnamed: 10  Unnamed: 11
# 0                    NaN                     NaN          NaN
# 1                    NaN                     NaN          NaN
# 2                    NaN                     NaN          NaN
# 3  Unavailable App Units  Web Referrer App Units          NaN
# 4                     42                    1915          0.0

# %%
# it seems that the first three rows are not needed. i will delete them.
df = df.drop(labels=[0,1,2], axis=0)

# %%
# checking to see if dropping the unneeded rows worked.
df.head()
# Out:
#         Name                Sample App                    Unnamed: 2  \
# 3       Date  App Referrer Impressions  App Store Browse Impressions
# 4  4/15/2017                      4333                         95458
# 5  4/16/2017                      4490                         89147
# 6  4/17/2017                      5347                         89628
# 7  4/18/2017                      4740                         91558
#
#                      Unnamed: 3               Unnamed: 4  \
# 3  App Store Search Impressions  Unavailable Impressions
# 4                         24877                        0
# 5                         24555                        0
# 6                         27073                        0
# 7                         29643                        0
#
#                  Unnamed: 5              Unnamed: 6  \
# 3  Web Referrer Impressions  App Referrer App Units
# 4                      5290                     827
# 5                      4877                     863
# 6                      7217                    1052
# 7                      7478                    1047
#
#                    Unnamed: 7                  Unnamed: 8  \
# 3  App Store Browse App Units  App Store Search App Units
# 4                         363                        4290
# 5                         403                        4093
# 6                         363                        4783
# 7                         430                        5440
#
#               Unnamed: 9             Unnamed: 10  Unnamed: 11
# 3  Unavailable App Units  Web Referrer App Units          NaN
# 4                     42                    1915          0.0
# 5                     25                    1838          0.0
# 6                     43                    2643          0.0
# 7                     38                    2765          0.0

# %%
# changing the name of the columns to the names in the first row.
df = df.rename(columns=df.iloc[0])
df.head()
# Out:
#         Date  App Referrer Impressions  App Store Browse Impressions  \
# 3       Date  App Referrer Impressions  App Store Browse Impressions
# 4  4/15/2017                      4333                         95458
# 5  4/16/2017                      4490                         89147
# 6  4/17/2017                      5347                         89628
# 7  4/18/2017                      4740                         91558
#
#    App Store Search Impressions  Unavailable Impressions  \
# 3  App Store Search Impressions  Unavailable Impressions
# 4                         24877                        0
# 5                         24555                        0
# 6                         27073                        0
# 7                         29643                        0
#
#    Web Referrer Impressions  App Referrer App Units  \
# 3  Web Referrer Impressions  App Referrer App Units
# 4                      5290                     827
# 5                      4877                     863
# 6                      7217                    1052
# 7                      7478                    1047
#
#    App Store Browse App Units  App Store Search App Units  \
# 3  App Store Browse App Units  App Store Search App Units
# 4                         363                        4290
# 5                         403                        4093
# 6                         363                        4783
# 7                         430                        5440
#
#    Unavailable App Units  Web Referrer App Units  NaN
# 3  Unavailable App Units  Web Referrer App Units  NaN
# 4                     42                    1915  0.0
# 5                     25                    1838  0.0
# 6                     43                    2643  0.0
# 7                     38                    2765  0.0

# %%
# great. now well delete the first row and last column because they are not needed....
df = df.drop(labels=[3], axis=0)
df.head()
# Out:
#         Date App Referrer Impressions App Store Browse Impressions  \
# 4  4/15/2017                     4333                        95458
# 5  4/16/2017                     4490                        89147
# 6  4/17/2017                     5347                        89628
# 7  4/18/2017                     4740                        91558
# 8  4/19/2017                     5422                        92908
#
#   App Store Search Impressions Unavailable Impressions  \
# 4                        24877                       0
# 5                        24555                       0
# 6                        27073                       0
# 7                        29643                       0
# 8                        30597                       0
#
#   Web Referrer Impressions App Referrer App Units App Store Browse App Units  \
# 4                     5290                    827                        363
# 5                     4877                    863                        403
# 6                     7217                   1052                        363
# 7                     7478                   1047                        430
# 8                     7802                   1132                        442
#
#   App Store Search App Units Unavailable App Units Web Referrer App Units  NaN
# 4                       4290                    42                   1915  0.0
# 5                       4093                    25                   1838  0.0
# 6                       4783                    43                   2643  0.0
# 7                       5440                    38                   2765  0.0
# 8                       5573                    43                   2820  0.0

# %%
# and reset the index numbers so that our dataframe is ready to go.
df = df.reset_index(drop=True)
df.head()
# Out:
#         Date App Referrer Impressions App Store Browse Impressions  \
# 0  4/15/2017                     4333                        95458
# 1  4/16/2017                     4490                        89147
# 2  4/17/2017                     5347                        89628
# 3  4/18/2017                     4740                        91558
# 4  4/19/2017                     5422                        92908
#
#   App Store Search Impressions Unavailable Impressions  \
# 0                        24877                       0
# 1                        24555                       0
# 2                        27073                       0
# 3                        29643                       0
# 4                        30597                       0
#
#   Web Referrer Impressions App Referrer App Units App Store Browse App Units  \
# 0                     5290                    827                        363
# 1                     4877                    863                        403
# 2                     7217                   1052                        363
# 3                     7478                   1047                        430
# 4                     7802                   1132                        442
#
#   App Store Search App Units Unavailable App Units Web Referrer App Units  NaN
# 0                       4290                    42                   1915  0.0
# 1                       4093                    25                   1838  0.0
# 2                       4783                    43                   2643  0.0
# 3                       5440                    38                   2765  0.0
# 4                       5573                    43                   2820  0.0

# %%
# making sure that the date is in the correct format
df['Date'] = pd.to_datetime(df['Date'])

# %%
# checking the dataframe to see if there are any missing values or something that catches my eye in the data.
# there are no missing values. what a relief. 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1389 entries, 0 to 1388
# Data columns (total 12 columns):
# Date                            1389 non-null datetime64[ns]
# App Referrer Impressions        1389 non-null object
# App Store Browse Impressions    1389 non-null object
# App Store Search Impressions    1389 non-null object
# Unavailable Impressions         1389 non-null object
# Web Referrer Impressions        1389 non-null object
# App Referrer App Units          1389 non-null object
# App Store Browse App Units      1389 non-null object
# App Store Search App Units      1389 non-null object
# Unavailable App Units           1389 non-null object
# Web Referrer App Units          1389 non-null object
# nan                             1389 non-null float64
# dtypes: datetime64[ns](1), float64(1), object(10)
# memory usage: 130.3+ KB

# %%
# I want to break the data down into before the and after the app store switch. that way we can visually see what if
# anything is happening.
df2 = df['10/28/2020':'2/1/2021']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-a180e7625d0b> in <module>
#       1 # I want to break the data down into before the and after the app store switch. that way we can visually see what if
#       2 # anything is happening.
# ----> 3 df2 = df['10/28/2020':'2/1/2021']
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2959
#    2960         # Do we have a slicer (on rows)?
# -> 2961         indexer = convert_to_index_sliceable(self, key)
#    2962         if indexer is not None:
#    2963             return self._slice(indexer, axis=0)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in convert_to_index_sliceable(obj, key)
#    2356     idx = obj.index
#    2357     if isinstance(key, slice):
# -> 2358         return idx._convert_slice_indexer(key, kind="getitem")
#    2359
#    2360     elif isinstance(key, str):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in _convert_slice_indexer(self, key, kind)
#    3188             if self.is_integer() or is_index_slice:
#    3189                 return slice(
# -> 3190                     self._validate_indexer("slice", key.start, kind),
#    3191                     self._validate_indexer("slice", key.stop, kind),
#    3192                     self._validate_indexer("slice", key.step, kind),
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in _validate_indexer(self, form, key, kind)
#    5069             pass
#    5070         elif kind in ["iloc", "getitem"]:
# -> 5071             self._invalid_indexer(form, key)
#    5072         return key
#    5073
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in _invalid_indexer(self, form, key)
#    3338             "cannot do {form} indexing on {klass} with these "
#    3339             "indexers [{key}] of {kind}".format(
# -> 3340                 form=form, klass=type(self), key=key, kind=type(key)
#    3341             )
#    3342         )
#
# TypeError: cannot do slice indexing on <class 'pandas.core.indexes.range.RangeIndex'> with these indexers [10/28/2020] of <class 'str'>

# %%
df['Date'].value_counts(ascending=True)
# Out:
# 2018-12-21    1
# 2018-02-01    1
# 2019-03-06    1
# 2019-07-27    1
# 2018-06-05    1
#              ..
# 2020-10-14    1
# 2019-02-23    1
# 2018-01-02    1
# 2020-12-15    1
# 2017-10-30    1
# Name: Date, Length: 1389, dtype: int64
